# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer 
import requests


def sentiment_scores(sentence): 
    sid_obj = SentimentIntensityAnalyzer() 
    
    sentiment_dict = sid_obj.polarity_scores(sentence) 
      
    print("Overall sentiment dictionary is : ", sentiment_dict) 
    print("sentence was rated as ", sentiment_dict['neg']*100, "% Negative") 
    print("sentence was rated as ", sentiment_dict['neu']*100, "% Neutral") 
    print("sentence was rated as ", sentiment_dict['pos']*100, "% Positive") 
  
    print("Sentence Overall Rated As", end = " ") 
  
    # decide sentiment as positive, negative and neutral 
    if sentiment_dict['compound'] >= 0.05 : 
        print("Positive") 
  
    elif sentiment_dict['compound'] <= - 0.05 : 
        print("Negative") 
  
    else : 
        print("Neutral")
  
def Headlines(): 
    # using keyword AAPL, to collect all Apple related stock news
    url = ('https://newsapi.org/v2/everything?'
       'q=AAPL&'
       'from=2020-01-29&'
       'sortBy=popularity&'
       'apiKey=7cb80385256e45589c40bfc9b5241e6b')
  
    open_bbc_page = requests.get(url).json() 
  
    article = open_bbc_page["articles"] 
    
    results = [] 
      
    for ar in article:
        results.append(ar["title"]) 
          
    for i in range(len(results)):
        print(i + 1, results[i]) 
        sentiment_scores(results[i])
        print('\n')
 
if __name__ == '__main__': 
    Headlines()
# Out:
# 1 Apple Now Worth More Than Germany's Entire DAX Stock Index
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 0.826, 'pos': 0.174, 'compound': 0.2263}
# sentence was rated as  0.0 % Negative
# sentence was rated as  82.6 % Neutral
# sentence was rated as  17.4 % Positive
# Sentence Overall Rated As Positive
#
#
# 2 Apple made a small change to the way it introduced its new iPhones this year, and its record-breaking holiday quarter proved it was a runaway success (AAPL)
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 0.782, 'pos': 0.218, 'compound': 0.7506}
# sentence was rated as  0.0 % Negative
# sentence was rated as  78.2 % Neutral
# sentence was rated as  21.8 % Positive
# Sentence Overall Rated As Positive
#
#
# 3 Apple is reportedly preparing to launch a new product called 'AirTags,' which will attach to items like keys or purses to help you find them if they're lost or missing (AAPL)
# Overall sentiment dictionary is :  {'neg': 0.126, 'neu': 0.728, 'pos': 0.146, 'compound': 0.1779}
# sentence was rated as  12.6 % Negative
# sentence was rated as  72.8 % Neutral
# sentence was rated as  14.6 % Positive
# Sentence Overall Rated As Positive
#
#
# 4 Dow Jones Today Propped By Apple, Dow, Boeing; Chips Stocks Mixed, The Fed's Coronavirus Question - Investor's Business Daily
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# sentence was rated as  0.0 % Negative
# sentence was rated as  100.0 % Neutral
# sentence was rated as  0.0 % Positive
# Sentence Overall Rated As Neutral
#
#
# 5 Analysts unsurprisingly impressed by AAPL earnings, many boost target prices
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 0.58, 'pos': 0.42, 'compound': 0.7003}
# sentence was rated as  0.0 % Negative
# sentence was rated as  57.99999999999999 % Neutral
# sentence was rated as  42.0 % Positive
# Sentence Overall Rated As Positive
#
#
# 6 Market Snapshot: Stock futures edge higher as earnings overshadow coronavirus worries
# Overall sentiment dictionary is :  {'neg': 0.219, 'neu': 0.781, 'pos': 0.0, 'compound': -0.4215}
# sentence was rated as  21.9 % Negative
# sentence was rated as  78.10000000000001 % Neutral
# sentence was rated as  0.0 % Positive
# Sentence Overall Rated As Negative
#
#
# 7 London Markets: Losses for oil companies, Diageo weigh on FTSE 100
# Overall sentiment dictionary is :  {'neg': 0.213, 'neu': 0.787, 'pos': 0.0, 'compound': -0.4019}
# sentence was rated as  21.3 % Negative
# sentence was rated as  78.7 % Neutral
# sentence was rated as  0.0 % Positive
# Sentence Overall Rated As Negative
#
#
# 8 The Ratings Game: Analysts divided on how much further Apple shares can climb after ‘blowout results’
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 0.872, 'pos': 0.128, 'compound': 0.296}
# sentence was rated as  0.0 % Negative
# sentence was rated as  87.2 % Neutral
# sentence was rated as  12.8 % Positive
# Sentence Overall Rated As Positive
#
#
# 9 Apple may have had blowout earnings, but these risks to the stock have emerged
# Overall sentiment dictionary is :  {'neg': 0.169, 'neu': 0.831, 'pos': 0.0, 'compound': -0.3919}
# sentence was rated as  16.900000000000002 % Negative
# sentence was rated as  83.1 % Neutral
# sentence was rated as  0.0 % Positive
# Sentence Overall Rated As Negative
#
#
# 10 MarketWatch First Take: Apple’s iPhone didn’t need 5G for a mind-boggling rebound
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# sentence was rated as  0.0 % Negative
# sentence was rated as  100.0 % Neutral
# sentence was rated as  0.0 % Positive
# Sentence Overall Rated As Neutral
#
#
# 11 Deep Dive: A hidden stock tip in Apple earnings? Watch these semiconductor companies, analyst says
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# sentence was rated as  0.0 % Negative
# sentence was rated as  100.0 % Neutral
# sentence was rated as  0.0 % Positive
# Sentence Overall Rated As Neutral
#
#
# 12 Cowen drives AAPL target to $370 on iPhone return to growth
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 0.794, 'pos': 0.206, 'compound': 0.3818}
# sentence was rated as  0.0 % Negative
# sentence was rated as  79.4 % Neutral
# sentence was rated as  20.599999999999998 % Positive
# Sentence Overall Rated As Positive
#
#
# 13 Tout va bien pour Apple : l’iPhone, les AirPods et les services cartonnent
# Overall sentiment dictionary is :  {'neg': 0.12, 'neu': 0.88, 'pos': 0.0, 'compound': -0.128}
# sentence was rated as  12.0 % Negative
# sentence was rated as  88.0 % Neutral
# sentence was rated as  0.0 % Positive
# Sentence Overall Rated As Negative
#
#
# 14 Apple Inc. (AAPL) Q1 2020 Earnings Call Transcript
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# sentence was rated as  0.0 % Negative
# sentence was rated as  100.0 % Neutral
# sentence was rated as  0.0 % Positive
# Sentence Overall Rated As Neutral
#
#
# 15 Apple Shatters Records in Blowout Fourth Quarter
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# sentence was rated as  0.0 % Negative
# sentence was rated as  100.0 % Neutral
# sentence was rated as  0.0 % Positive
# Sentence Overall Rated As Neutral
#
#
# 16 Apple blamed China's coronavirus for a 'wider-than-usual' $4 billion range in its revenue forecast. But the weird thing is, a $4 billion range is not actually unusual for Apple. (AAPL)
# Overall sentiment dictionary is :  {'neg': 0.136, 'neu': 0.864, 'pos': 0.0, 'compound': -0.4767}
# sentence was rated as  13.600000000000001 % Negative
# sentence was rated as  86.4 % Neutral
# sentence was rated as  0.0 % Positive
# Sentence Overall Rated As Negative
#
#
# 17 Apple’s Stunning Results Suggest The Stock Is Still Too Cheap
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 0.776, 'pos': 0.224, 'compound': 0.3818}
# sentence was rated as  0.0 % Negative
# sentence was rated as  77.60000000000001 % Neutral
# sentence was rated as  22.400000000000002 % Positive
# Sentence Overall Rated As Positive
#
#
# 18 Il valore di Apple supera quello dell’intero indice DAX tedesco
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# sentence was rated as  0.0 % Negative
# sentence was rated as  100.0 % Neutral
# sentence was rated as  0.0 % Positive
# Sentence Overall Rated As Neutral
#
#
# 19 Dow Jones Futures: Apple, AMD, Xilinx Earnings Fuel Big Chip Moves After Stock Market Rally Rebounds From Coronavirus Sell-Off - Investor's Business Daily
# Overall sentiment dictionary is :  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# sentence was rated as  0.0 % Negative
# sentence was rated as  100.0 % Neutral
# sentence was rated as  0.0 % Positive
# Sentence Overall Rated As Neutral
#
#
# 20 Apple Is Either A Hardware Or A Consumer Company, If It's The Former We're Going Lower
# Overall sentiment dictionary is :  {'neg': 0.145, 'neu': 0.855, 'pos': 0.0, 'compound': -0.296}
# sentence was rated as  14.499999999999998 % Negative
# sentence was rated as  85.5 % Neutral
# sentence was rated as  0.0 % Positive
# Sentence Overall Rated As Negative
